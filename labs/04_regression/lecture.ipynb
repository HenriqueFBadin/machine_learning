# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([ 
    [1],
    [5],
    [2],
    [4],
])

y = np.array([
    [1],
    [2],
    [1.3],
    [1.7],
])

# %%
plt.figure()
plt.scatter(X, y)
plt.show()

# %%
x_plot = np.linspace(0, 6, 100).reshape(-1, 1)

theta_0 = 0.75
theta_1 = 0.25

y_plot = theta_0 + x_plot * theta_1

# %%
plt.figure()
plt.scatter(X, y)
plt.plot(x_plot, y_plot, color='red')
plt.show()

# %%
A = np.array([
    [2, 6],
    [24, 92],
])

b = np.array([
    [3],
    [40.8],
])

# %%
np.linalg.solve(A, b)
# Out:
# array([[0.78],
#        [0.24]])

# %%
np.linalg.inv(A) @ b
# Out:
# array([[0.78],
#        [0.24]])

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)

model.intercept_, model.coef_
# Out:
# (array([0.78]), array([[0.24]]))

# %%
x_plot = np.linspace(0, 6, 100).reshape(-1, 1)
y_plot = model.predict(x_plot)

# %%
plt.figure()
plt.scatter(X, y)
plt.plot(x_plot, y_plot, color='red')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 1000

X = np.random.uniform(-3.0, 3.0, [n, 1])
y = 0.5 * X**2 + X + 2 + np.random.normal(0, 1, [n, 1])

# %%
plt.figure()
plt.scatter(X, y)
plt.show()

# %%
X_aug = np.concatenate([np.ones([n, 1]), X, X**2], axis=1)

# %%
X_aug[:5, :]
# Out:
# array([[ 1.00000000e+00,  3.06483299e-03,  9.39320124e-06],
#        [ 1.00000000e+00, -1.30820739e-01,  1.71140657e-02],
#        [ 1.00000000e+00, -1.44990610e+00,  2.10222770e+00],
#        [ 1.00000000e+00, -1.42683421e+00,  2.03585586e+00],
#        [ 1.00000000e+00, -8.35923854e-01,  6.98768690e-01]])

# %%
X.shape, X_aug.shape
# Out:
# ((1000, 1), (1000, 3))

# %%
theta = np.linalg.inv(X_aug.T @ X_aug) @ X_aug.T @ y

# %%
theta
# Out:
# array([[2.01809465],
#        [1.01770208],
#        [0.49651413]])
